# %% [markdown]
# # Introduction
#
# 1. Modify the time course plot with sex as a variable
# 2. Add symbols for State 14 replicates

# %% [markdown]
# ## Load packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Process data

# %%
df_fpkms = pd.read_csv( "../../qbb2021/data/fpkms.csv", index_col = "t_name") # explicitly identify the col name

df_replic = pd.read_csv( "../../qbb2021/data/replicates.csv", index_col = "t_name") # load the replicate file

df_replic
# Out:
#               male_14A   male_14B   male_14C   male_14D  female_14A  \
# t_name
# FBtr0114258   0.000000   0.000000   0.000000   0.000000    0.000000
# FBtr0346770   0.000000   0.000000   0.000000   0.000000    0.000000
# FBtr0302440   0.000000   0.000000   0.000000   0.000000    0.000000
# FBtr0302347  22.995892  38.139065  11.577139  20.456739   60.885391
# FBtr0346769   0.000000   0.000000   0.000000   0.000000    0.000000
# ...                ...        ...        ...        ...         ...
# FBtr0114187   0.000000   0.000000   0.000000   0.000000    0.000000
# FBtr0304147   0.000000   0.000000   0.000000   0.000000    0.000000
# FBtr0114216   1.459697   0.731757   2.716971  65.821503    2.207145
# FBtr0114222   0.000000   0.000000   0.000000   0.000000    0.000000
# FBtr0114283   0.000000   0.000000   0.000000   0.000000    0.000000
#
#              female_14B  female_14C  female_14D gene_name
# t_name
# FBtr0114258    0.000000    0.000000    0.000000   CR41571
# ...

# %%
df_sxl_male = df_fpkms.loc["FBtr0331261", "male_10":"male_14D"]# Get FBtr0331261 male expression data
df_sxl_female = df_fpkms.loc["FBtr0331261", "female_10":"female_14D"]# Get FBtr0331261 female expression data

df_replic_male = df_replic.loc["FBtr0331261", "male_14A":"male_14D"]
df_replic_female = df_replic.loc["FBtr0331261", "female_14A":"female_14D"]

# %%
x = ['10', '11', '12', '13', '14A', '14B', '14C', '14D']
x_replic = ['14A', '14B', '14C', '14D']

# %% [markdown]
# ## Plot

# %%
fig, ax = plt.subplots()
ax.plot(x, df_sxl_male, label = "Male")

ax.scatter(x_replic, df_replic_male, label = "Male replicates", marker = '+', s = 100, c = 'red') 

ax.plot(x,df_sxl_female, label = "Female")

ax.scatter(x_replic, df_replic_female, label = "Female replicates", marker = '+', s = 100, c = 'purple')

ax.set_title ("Sex difference in the expression of FBtr0331261 in different stages", loc = 'center')
ax.set_xlabel("Developmental stage")
ax.set_ylabel("mRNA abundance (RPKM)")
ax.legend()
fig.savefig("../../qbb2021-answers/day4-lunch/Time_series.png")
plt.show()
